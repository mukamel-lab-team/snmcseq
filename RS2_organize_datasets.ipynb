# %%
from __init__ import *
import matplotlib.pyplot as plt

import snmcseq_utils

# %%
# RS1 mapping summary example

# f2 = os.path.join(PATH_DATASETS, 'CEMBA_3C_171206', 'mapping_summary_CEMBA_3C_171206.tsv')
# df2 = pd.read_table(f2)
# print(df2.shape)
# df2.head()

# %%
# add header to RS2 mapping summary
# dataset = 'CEMBA_RS2_17Q4'
# f = os.path.join(PATH_DATASETS, dataset, '17Q4_meta.txt')
# df = pd.read_table(f, header=None, names=df2.columns.tolist()[:15] + ['RS2'])
# output = os.path.join(PATH_DATASETS, dataset, 'mapping_summary_{}.tsv'.format(dataset))
# df.to_csv(output, sep='\t', na_rep='NA', header=True, index=False)
# print(df.shape)
# df.head()

# %%
dataset = 'CEMBA_RS2_17Q4'
f = os.path.join(PATH_DATASETS, dataset, 'mapping_summary_{}.tsv'.format(dataset))
df = pd.read_table(f)
print(df.shape)
df.head()
# Out:
# (1330, 16)
#                                               Sample  Total reads  \
# 0  180118_CEMBA_mm_P56_P63_RS2_180117_P1_180117_P...      3389710
# 1  180118_CEMBA_mm_P56_P63_RS2_180117_P1_180117_P...      2541566
# 2  180118_CEMBA_mm_P56_P63_RS2_180117_P1_180117_P...      2395806
# 3  180118_CEMBA_mm_P56_P63_RS2_180117_P1_180117_P...      2876000
# 4  180118_CEMBA_mm_P56_P63_RS2_180117_P1_180117_P...      2833108
#
#    Mapped reads  Mapping rate  Nonclonal reads  % Nonclonal rate  \
# 0       2254035         0.665          1696759             0.753
# 1       1708816         0.672          1354285             0.793
# 2       1596249         0.666          1284626             0.805
# 3       1954338         0.680          1516577             0.776
# 4       1917974         0.677          1543076             0.805
#
#    Filtered reads  Filtered rate  Lambda mC/C  mCCC/CCC   mCG/CG   mCH/CH  \
# 0         1431998          0.844      0.00752   0.00643  0.78692  0.03131
# 1         1154754          0.853      0.01015   0.00700  0.77428  0.03527
# 2         1083669          0.844      0.00000   0.00635  0.76298  0.03217
# 3         1295196          0.854      0.00000   0.00641  0.79136  0.02963
# 4         1314413          0.852      0.00000   0.00672  0.76906  0.03331
#
#    Estimated mCG/CG  Estimated mCH/CH  % Genome covered                    RS2
# 0           0.78554           0.02504              5.98  Tf3C MOP 3C SC female
# 1           0.77269           0.02847              4.90  Tf3C MOP 3C SC female
# 2           0.76147           0.02599              4.61  Tf3C MOP 3C SC female
# 3           0.79001           0.02337              5.47  Tf3C MOP 3C SC female
# 4           0.76750           0.02677              5.57  Tf3C MOP 3C SC female

# %%
df.groupby('RS2').count()
# Out:
#                            Sample  Total reads  Mapped reads  Mapping rate  \
# RS2
# Bm3C_rep1 MOP 3C SSp male      91           91            91            91
# Bm3C_rep2 MOP 3C SSp male      50           50            50            50
# Bm4B_rep1 MOP 4B SSp male      89           89            89            89
# Bm4B_rep2 MOP 4B SSp male      83           83            83            83
# Pf3C MOP 3C STR female         96           96            96            96
# Pf4B MOP 4B STR female         95           95            95            95
# Pm3C MOP 3C STR male           82           82            82            82
# Pm4B MOP 4B STR male           92           92            92            92
# Tf3C MOP 3C SC female          55           55            55            55
# Tf4B MOP 4B SC female          92           92            92            92
# Tf6B SSp 6B SC female          85           85            85            85
# Tf7B SSp 7B SC female          82           82            82            82
# Tm3C MOP 3C SC male            82           82            82            82
# Tm4B MOP 4B SC male            86           86            86            86
# Tm6B SSp 6B SC male            89           89            89            89
# Tm7B SSp 7B SC male            81           81            81            81
#
#                            Nonclonal reads  % Nonclonal rate  Filtered reads  \
# RS2
# Bm3C_rep1 MOP 3C SSp male               91                91              91
# Bm3C_rep2 MOP 3C SSp male               50                50              50
# Bm4B_rep1 MOP 4B SSp male               89                89              89
# Bm4B_rep2 MOP 4B SSp male               83                83              83
# Pf3C MOP 3C STR female                  96                96              96
# Pf4B MOP 4B STR female                  95                95              95
# Pm3C MOP 3C STR male                    82                82              82
# Pm4B MOP 4B STR male                    92                92              92
# Tf3C MOP 3C SC female                   55                55              55
# Tf4B MOP 4B SC female                   92                92              92
# Tf6B SSp 6B SC female                   85                85              85
# Tf7B SSp 7B SC female                   82                82              82
# Tm3C MOP 3C SC male                     82                82              82
# Tm4B MOP 4B SC male                     86                86              86
# Tm6B SSp 6B SC male                     89                89              89
# Tm7B SSp 7B SC male                     81                81              81
#
#                            Filtered rate  Lambda mC/C  mCCC/CCC  mCG/CG  \
# RS2
# Bm3C_rep1 MOP 3C SSp male             91           54        91      91
# Bm3C_rep2 MOP 3C SSp male             50           31        50      50
# Bm4B_rep1 MOP 4B SSp male             89           41        89      89
# Bm4B_rep2 MOP 4B SSp male             83           43        83      83
# Pf3C MOP 3C STR female                96            1        96      96
# Pf4B MOP 4B STR female                95           48        95      95
# Pm3C MOP 3C STR male                  82           56        82      82
# Pm4B MOP 4B STR male                  92           44        92      92
# Tf3C MOP 3C SC female                 55           41        55      55
# Tf4B MOP 4B SC female                 92           49        92      92
# Tf6B SSp 6B SC female                 85           53        85      85
# Tf7B SSp 7B SC female                 82           49        82      82
# Tm3C MOP 3C SC male                   82           65        82      82
# Tm4B MOP 4B SC male                   86           45        86      86
# Tm6B SSp 6B SC male                   89           56        89      89
# Tm7B SSp 7B SC male                   81           47        81      81
#
#                            mCH/CH  Estimated mCG/CG  Estimated mCH/CH  \
# RS2
# Bm3C_rep1 MOP 3C SSp male      91                91                91
# Bm3C_rep2 MOP 3C SSp male      50                50                50
# Bm4B_rep1 MOP 4B SSp male      89                89                89
# Bm4B_rep2 MOP 4B SSp male      83                83                83
# Pf3C MOP 3C STR female         96                96                96
# Pf4B MOP 4B STR female         95                95                95
# Pm3C MOP 3C STR male           82                82                82
# Pm4B MOP 4B STR male           92                92                92
# Tf3C MOP 3C SC female          55                55                55
# Tf4B MOP 4B SC female          92                92                92
# Tf6B SSp 6B SC female          85                85                85
# Tf7B SSp 7B SC female          82                82                82
# Tm3C MOP 3C SC male            82                82                82
# Tm4B MOP 4B SC male            86                86                86
# Tm6B SSp 6B SC male            89                89                89
# Tm7B SSp 7B SC male            81                81                81
#
#                            % Genome covered
# RS2
# Bm3C_rep1 MOP 3C SSp male                91
# Bm3C_rep2 MOP 3C SSp male                50
# Bm4B_rep1 MOP 4B SSp male                89
# Bm4B_rep2 MOP 4B SSp male                83
# Pf3C MOP 3C STR female                   96
# Pf4B MOP 4B STR female                   95
# Pm3C MOP 3C STR male                     82
# Pm4B MOP 4B STR male                     92
# Tf3C MOP 3C SC female                    55
# Tf4B MOP 4B SC female                    92
# Tf6B SSp 6B SC female                    85
# Tf7B SSp 7B SC female                    82
# Tm3C MOP 3C SC male                      82
# Tm4B MOP 4B SC male                      86
# Tm6B SSp 6B SC male                      89
# Tm7B SSp 7B SC male                      81

# %%
# create dataset dir and split mapping summary
for rs2_code, df_sub in df.groupby('RS2'):
    rs2_code = rs2_code.split(' ')
    dataset = 'CEMBA_RS2_{}'.format(rs2_code[0])
    # create dataset dir
    os.makedirs(os.path.join(PATH_DATASETS, dataset))
    # copy metadata over
    df_sub = df_sub.drop('RS2', axis=1)
    df_sub.to_csv(os.path.join(PATH_DATASETS, d taset, 'mapping_summary_{}.tsv'.format(dataset)), 
                  sep='\t', na_rep='NA', header=True, index=False)
    print(df_sub.shape)
# Out:
# (91, 15)
# (50, 15)
# (89, 15)
# (83, 15)
# (96, 15)
# (95, 15)
# (82, 15)
# (92, 15)
# (55, 15)
# (92, 15)
# (85, 15)
# (82, 15)
# (82, 15)
# (86, 15)
# (89, 15)
# (81, 15)

# %%
# distribute files over 
dataset_origin = 'CEMBA_RS2_17Q4'
for rs2_code, df_sub in df.groupby('RS2'):
    rs2_code = rs2_code.split(' ')
    # dataset
    dataset = 'CEMBA_RS2_{}'.format(rs2_code[0])
    
    # cells in the dataset
    cells = df_sub['Sample'].values
    
    allc_srcs = [os.path.join(PATH_DATASETS, dataset_origin, 'allc', 'allc_{}.tsv.bgz'.format(cell))
                 for cell in cells]
    allc_dsts = [os.path.join(PATH_DATASETS, dataset, 'allc', 
                              os.path.basename(allc_src)) for allc_src in allc_srcs] 
    
    # create allc dir
    if not os.path.isdir(os.path.join(PATH_DATASETS, dataset, 'allc')): 
        os.makedirs(os.path.join(PATH_DATASETS, dataset, 'allc'))
        
#     for src, dst in zip(allc_srcs, allc_dsts):
#         os.rename(src, dst)

        
#     # create binc dir
#     if not os.path.isdir(os.path.join(PATH_DATASETS, dataset, 'binc')): 
#         os.makedirs(os.path.join(PATH_DATASETS, dataset, 'binc'))
        
#     # create gene_level dir
#     if not os.path.isdir(os.path.join(PATH_DATASETS, dataset, 'gene_level')): 
#         os.makedirs(os.path.join(PATH_DATASETS, dataset, 'gene_level'))

#     allc_tabix_srcs = [os.path.join(PATH_DATASETS, dataset_origin, 'allc', 'allc_{}.tsv.bgz.tbi'.format(cell))
#                  for cell in cells]
#     allc_tabix_dsts = [os.path.join(PATH_DATASETS, dataset, 'allc', 
#                               os.path.basename(allc_tabix_src)) for allc_tabix_src in allc_tabix_srcs] 
    
#     binc_srcs = [os.path.join(PATH_DATASETS, dataset_origin, 'binc', 'binc_{}_10000.tsv.bgz'.format(cell))
#                  for cell in cells]
#     binc_dsts = [os.path.join(PATH_DATASETS, dataset, 'binc', 
#                               os.path.basename(binc_src)) for binc_src in binc_srcs] 
    
#     genebody_srcs = [os.path.join(PATH_DATASETS, dataset_origin, 'gene_level', 'genebody_{}.tsv.bgz'.format(cell))
#                  for cell in cells]
#     genebody_dsts = [os.path.join(PATH_DATASETS, dataset, 'gene_level', 
#                               os.path.basename(genebody_src)) for genebody_src in genebody_srcs] 
        
#     print(binc_srcs[:1]) 
#     print(binc_dsts[:1]) 
#     print(genebody_srcs[:1]) 
#     print(genebody_dsts[:1]) 

#     for src, dst in zip(allc_tabix_srcs, allc_tabix_dsts):
#         os.rename(src, dst)

#     for src, dst in zip(binc_srcs, binc_dsts):
#         try:
#             os.rename(src, dst)
#         except:
#             pass
#     for src, dst in zip(genebody_srcs, genebody_dsts):
#         try:
#             os.rename(src, dst)
#         except:
#             pass

# %%
# check if all datasets are good dataset
with snmcseq_utils.cd(PATH_DATASETS):
    datasets = sorted(glob.glob('*'))
for dataset in datasets:
    with snmcseq_utils.cd(os.path.join(PATH_DATASETS, dataset)):
        try:
            df_meta = pd.read_table('mapping_summary_{}.tsv'.format(dataset))
            n_cells = df_meta.shape[0]
        except:
            print(dataset, "Error in opening mapping summary")
            continue
        
        n_allc = len(glob.glob('./allc/allc_*.tsv.bgz'))
        n_allc_tbi = len(glob.glob('./allc/allc_*.tsv.bgz.tbi'))
        
        n_binc = len(glob.glob('./binc/binc_*.tsv.bgz'))
        n_genebody = len(glob.glob('./gene_level/genebody_*.tsv.bgz'))
        
        flag = 0
        if n_cells != n_allc:
            print(dataset, n_cells, 'Error allc! ({})'.format(n_allc))
            flag += 1
        if n_cells != n_allc_tbi:
            print(dataset, n_cells, 'Error allc tabix! ({})'.format(n_allc_tbi))
            flag += 1
        if n_cells != n_binc:
            print(dataset, n_cells, 'Error binc! ({})'.format(n_binc))
            flag += 1
        if n_cells != n_genebody:
            print(dataset, n_cells, 'Error genebody! ({})'.format(n_genebody))
            flag += 1
        
        if flag == 0:
            pass
            print(dataset, n_cells, "All good!")
# Out:
# CEMBA_3A_180129 1384 All good!
# CEMBA_3A_180130 1291 All good!
# CEMBA_3C_171206 1202 All good!
# CEMBA_3C_171207 1270 All good!
# CEMBA_3F_180109 1059 All good!
# CEMBA_4B_171212 296 All good!
# CEMBA_4B_171213 1261 All good!
# CEMBA_4B_180104 1323 All good!
# CEMBA_4D_171214 1106 All good!
# CEMBA_4D_171219 1433 All good!
# CEMBA_RS2_Bm3C_rep1 91 All good!
# CEMBA_RS2_Bm3C_rep2 50 All good!
# CEMBA_RS2_Bm4B_rep1 89 All good!
# CEMBA_RS2_Bm4B_rep2 83 All good!
# CEMBA_RS2_Pf3C 96 All good!
# CEMBA_RS2_Pf4B 95 All good!
# CEMBA_RS2_Pm3C 82 All good!
# CEMBA_RS2_Pm4B 92 All good!
# CEMBA_RS2_Tf3C 55 All good!
# CEMBA_RS2_Tf4B 92 All good!
# CEMBA_RS2_Tf6B 85 All good!
# CEMBA_RS2_Tf7B 82 All good!
# CEMBA_RS2_Tm3C 82 All good!
# CEMBA_RS2_Tm4B 86 All good!
# CEMBA_RS2_Tm6B 89 All good!
# CEMBA_RS2_Tm7B 81 All good!

# %%
dataset = 'CEMBA_3A_180129'
with snmcseq_utils.cd(os.path.join(PATH_DATASETS, dataset, 'allc')):
    allc_files = glob.glob('*.bgz')
    cells = [allc_file[len('allc_'):-len('.tsv.bgz')] for allc_file in allc_files]
    
with snmcseq_utils.cd(os.path.join(PATH_DATASETS, dataset, 'gene_level')):
    files = glob.glob('*')
    cells_redo = []
    for cell in cells:
        if 'genebody_'+cell+'.tsv.bgz' not in files:
            cells_redo.append(cell)
cells_redo
# Out:
# []

# %%
import CEMBA_mc_gene_level
log = snmcseq_utils.create_logger()

for cell in cells_redo:
    allc_file = os.path.join(PATH_DATASETS, dataset, 'allc', 'allc_' + cell + '.tsv.bgz')

    CEMBA_mc_gene_level.mc_gene_level(allc_file,
        contexts=CONTEXTS, 
        genebody=GENEBODY,
        convention='CEMBA', 
        overwrite=False)
# Out:
# 04/13/2018 01:58:12 PM mc_gene_level processing: /cndd/Public_Datasets/CEMBA/snmCSeq/Datasets/CEMBA_3A_180129/allc/allc_180215_CEMBA_mm_P56_P63_3A_CEMBA180129_3A_3_CEMBA180129_3A_4_E9_AD006_indexed.tsv.bgz ['CH', 'CG', 'CA']
# 04/13/2018 01:59:18 PM Done with mc_gene_level processing: /cndd/Public_Datasets/CEMBA/snmCSeq/Datasets/CEMBA_3A_180129/allc/allc_180215_CEMBA_mm_P56_P63_3A_CEMBA180129_3A_3_CEMBA180129_3A_4_E9_AD006_indexed.tsv.bgz ['CH', 'CG', 'CA']
#  Saving results to /cndd/Public_Datasets/CEMBA/snmCSeq/Datasets/CEMBA_3A_180129/gene_level/genebody_180215_CEMBA_mm_P56_P63_3A_CEMBA180129_3A_3_CEMBA180129_3A_4_E9_AD006_indexed.tsv

# %%
dataset = 'CEMBA_4D_171214'
with snmcseq_utils.cd(os.path.join(PATH_DATASETS, dataset, 'allc')):
    allc_files = glob.glob('*.bgz')
    cells = [allc_file[len('allc_'):-len('.tsv.bgz')] for allc_file in allc_files]
    
with snmcseq_utils.cd(os.path.join(PATH_DATASETS, dataset, 'binc')):
    files = glob.glob('*')
    cells_redo = []
    for cell in cells:
        if 'binc_'+cell+'_10000.tsv.bgz' not in files:
            cells_redo.append(cell)
cells_redo
# Out:
# ['171222_CEMBA_mm_P56_P63_4D_CEMBA171214_4D_1_CEMBA171214_4D_2_B5_AD006_indexed']

# %%
import CEMBA_bin_allc_files

log = snmcseq_utils.create_logger()
for cell in cells_redo:
    allc_file = os.path.join(PATH_DATASETS, dataset, 'allc', 'allc_' + cell + '.tsv.bgz')
    
    CEMBA_bin_allc_files.bin_allc(allc_file, 
        convention='CEMBA',
        bin_size=BIN_SIZE, 
        contexts=CONTEXTS,
        chromosomes=None, 
        species='mouse',
        compression='gzip',
        overwrite=False
        )
# Out:
# 04/03/2018 05:54:43 PM binc processing: /cndd/Public_Datasets/CEMBA/snmCSeq/Datasets/CEMBA_4D_171214/allc/allc_171222_CEMBA_mm_P56_P63_4D_CEMBA171214_4D_1_CEMBA171214_4D_2_B5_AD006_indexed.tsv.bgz ['CH', 'CG', 'CA']
# 04/03/2018 05:56:51 PM Done with binc processing: /cndd/Public_Datasets/CEMBA/snmCSeq/Datasets/CEMBA_4D_171214/allc/allc_171222_CEMBA_mm_P56_P63_4D_CEMBA171214_4D_1_CEMBA171214_4D_2_B5_AD006_indexed.tsv.bgz ['CH', 'CG', 'CA']
# Saving results to: /cndd/Public_Datasets/CEMBA/snmCSeq/Datasets/CEMBA_4D_171214/binc/binc_171222_CEMBA_mm_P56_P63_4D_CEMBA171214_4D_1_CEMBA171214_4D_2_B5_AD006_indexed_10000.tsv
