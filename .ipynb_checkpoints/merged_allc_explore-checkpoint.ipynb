# %%
from __init__ import *
from natsort import natsorted
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
import itertools
import scipy.cluster.hierarchy as sch

import snmcseq_utils

# %%
def get_mcc(df, base_call_cutoff=100, sufficient_coverage_fraction=1):
    """Get mcc matrix from mc_c matrix (filtering out low coverage gene or bins)
    """
    logging.info('Getting mcc matrix from mc and c') 
    logging.info('base_call_cutoff={}, sufficient_coverage_fraction={}'.format(
                base_call_cutoff, sufficient_coverage_fraction))
    
    df_c = df.filter(regex="_c$")
    df_c.columns = [col[:-len('_c')] for col in df_c.columns] 
    df_mc = df.filter(regex="_mc$")
    df_mc.columns = [col[:-len('_mc')] for col in df_mc.columns] 
    # a gene is sufficiently covered in % of cells 
    condition = (df_c > base_call_cutoff).sum(axis=1) >= sufficient_coverage_fraction*(df.shape[1])/2.0 

    logging.info("Matrix size before pruning... "+ str(df.shape))
    logging.info("Matrix size after pruning... "+ str(df.loc[condition].shape))
    
    # get mcc matrix with kept bins and nan values for low coverage sites
    df_c_nan = df_c.copy()
    df_c_nan[df_c < base_call_cutoff] = np.nan
    df_mcc = df_mc.loc[condition]/df_c_nan.loc[condition]
    logging.info(df_mcc.shape)

    # imputation (missing value -> mean value of all cells)
    logging.info('Imputing data... (No effect if sufficient_coverage_fraction=1)')
    means = df_mcc.mean(axis=1)
    fill_value = pd.DataFrame({col: means for col in df_mcc.columns})
    df_mcc.fillna(fill_value, inplace=True)
    
    # add suffix
    df_mcc.columns = df_mcc.columns.values + '_mcc'
    
    return df_mcc

# %%
ens = 'Ens0'
files = natsorted(glob.glob(os.path.join(PATH_ENSEMBLES, ens, 'allc_merged', 'allc_merged_*_mergestrands*.tsv'))) 
f = os.path.join(PATH_ENSEMBLES, ens, '{}.tsv'.format(ens))
df_info = pd.read_table(f, index_col='cell_name')
f = os.path.join(PATH_ENSEMBLES, ens, 'tsne', 'tsne_perp30_binc_mCHmCG_human_combined_100000_summary_nmcc_v3.tsv')
df_tsne = pd.read_table(f, index_col='sample')
df_info = pd.merge(df_info, df_tsne, left_index=True, right_index=True)
df_info.head()
# Out:
#                                                  dataset  cluster annotation  \
# 160729_MB_v1_hs_25yr_MFG_pool_1000_AD008_indexed   MB_v1        8     hSst-2
# 160729_MB_v1_hs_25yr_MFG_pool_1019_AD006_indexed   MB_v1        8     hSst-2
# 160729_MB_v1_hs_25yr_MFG_pool_101_AD010_indexed    MB_v1        8     hSst-2
# 160729_MB_v1_hs_25yr_MFG_pool_1022_AD006_indexed   MB_v1        8     hSst-2
# 160729_MB_v1_hs_25yr_MFG_pool_1033_AD002_indexed   MB_v1        8     hSst-2
#
#                                                      tsne_x     tsne_y
# 160729_MB_v1_hs_25yr_MFG_pool_1000_AD008_indexed   4.023829  50.359272
# 160729_MB_v1_hs_25yr_MFG_pool_1019_AD006_indexed -24.774567  89.472031
# 160729_MB_v1_hs_25yr_MFG_pool_101_AD010_indexed  -11.439241  80.250549
# 160729_MB_v1_hs_25yr_MFG_pool_1022_AD006_indexed   3.210637  48.236778
# 160729_MB_v1_hs_25yr_MFG_pool_1033_AD002_indexed -21.555132  89.407265

# %%
df_annot = df_info.groupby('cluster').first().fillna('Glia/unlabeled')
df_annot_2 = df_info[['dataset', 'cluster']].groupby('cluster').count().rename(columns={'dataset': 'num'})
df_annot = pd.merge(df_annot, df_annot_2, left_index=True, right_index=True) 
df_annot.head()
# Out:
#         dataset annotation     tsne_x     tsne_y  num
# cluster
# 1         MB_v1      hL2/3 -45.348984 -54.049755  698
# 2         MB_v1      hL2/3  19.382914 -40.269714  618
# 3         MB_v1      hDL-1 -26.467854 -24.549786  400
# 4         MB_v1      hL2/3 -20.389982 -52.397022  353
# 5         MB_v1      hPv-1 -12.219467  64.979980  343

# %%
allc_fs = []
for f in files:
    allc_f = pd.read_table(f, header=None, names=['chr', 'pos', 'strand', 'context', 'mc', 'c', 'methylation'], iterator=True)
    allc_fs.append(allc_f)

# %%
covs = []
size = 100000
for allc_f in allc_fs:
    df = allc_f.get_chunk(size)
    covs.append(df['c'].sum()/size)

# %%
num_cells = df_info.groupby('cluster').count()['dataset'].values

fig, ax = plt.subplots()
ax.plot(covs)
        #/np.sum(covs), label='frac coverage')
# ax.plot(num_cells, label='frac num_cells')
ax.legend()
plt.show()
# Out:
# /cndd/fangming/venvs/venv_dobro_snmcseq/lib/python3.5/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
snmcseq_utils.plot_tsne_labels(df_info, tc='cluster')
snmcseq_utils.plot_tsne_labels(df_info, tc='annotation')

# %%
f = os.path.join(PATH_ENSEMBLES, ens, 'gene_level', 'genebody_mCH_human_combined_summary.tsv')
df_input = pd.read_table(f)

# %%
df_input.head()
# Out:
#                    id  160729_MB_v1_hs_25yr_MFG_pool_1000_AD008_indexed_mc  \
# 0  ENSG00000000003.10                                                  0
# 1   ENSG00000000005.5                                                  9
# 2   ENSG00000000419.8                                                  1
# 3   ENSG00000000457.9                                                  7
# 4  ENSG00000000460.12                                                109
#
#    160729_MB_v1_hs_25yr_MFG_pool_1000_AD008_indexed_c  \
# 0                                                  0
# 1                                                 56
# 2                                                178
# 3                                                339
# 4                                               3372
#
#    160729_MB_v1_hs_25yr_MFG_pool_1000_AD010_indexed_mc  \
# 0                                                  0
# 1                                                 15
# 2                                                  2
# 3                                                 15
# 4                                                 84
#
#    160729_MB_v1_hs_25yr_MFG_pool_1000_AD010_indexed_c  \
# 0                                                 71
# 1                                                163
# 2                                                505
# 3                                                499
# 4                                               2344
#
#    160729_MB_v1_hs_25yr_MFG_pool_1001_AD008_indexed_mc  \
# 0                                                  5
# 1                                                  7
# 2                                                  2
# 3                                                 22
# 4                                                159
#
#    160729_MB_v1_hs_25yr_MFG_pool_1001_AD008_indexed_c  \
# 0                                                 54
# 1                                                129
# 2                                                412
# 3                                                632
# 4                                               3729
#
#    160729_MB_v1_hs_25yr_MFG_pool_1001_AD010_indexed_mc  \
# 0                                                  4
# 1                                                  0
# 2                                                  1
# 3                                                  6
# 4                                                 70
#
#    160729_MB_v1_hs_25yr_MFG_pool_1001_AD010_indexed_c  \
# 0                                                 69
# 1                                                  0
# 2                                                707
# 3                                                540
# 4                                               2386
#
#    160729_MB_v1_hs_25yr_MFG_pool_1002_AD010_indexed_mc  \
# 0                                                  5
# 1                                                  4
# 2                                                  2
# 3                                                  5
# 4                                                 89
#
#                            ...                           \
# 0                          ...
# 1                          ...
# 2                          ...
# 3                          ...
# 4                          ...
#
#    171030_MB_EB_hs_25yr_BA10_FCU2_NA_H8_AD006_indexed_mc  \
# 0                                                  3
# 1                                                 13
# 2                                                  5
# 3                                                 11
# 4                                                172
#
#    171030_MB_EB_hs_25yr_BA10_FCU2_NA_H8_AD006_indexed_c  \
# 0                                                 67
# 1                                                198
# 2                                                348
# 3                                                560
# 4                                               2848
#
#    171030_MB_EB_hs_25yr_BA10_FCU2_NA_H8_AD008_indexed_mc  \
# 0                                                  0
# 1                                                  0
# 2                                                  2
# 3                                                  7
# 4                                                 61
#
#    171030_MB_EB_hs_25yr_BA10_FCU2_NA_H8_AD008_indexed_c  \
# 0                                                  0
# 1                                                  0
# 2                                                160
# 3                                                433
# 4                                               1637
#
#    171030_MB_EB_hs_25yr_BA10_FCU2_NA_H8_AD010_indexed_mc  \
# 0                                                  3
# 1                                                  2
# 2                                                  6
# 3                                                  8
# 4                                                144
#
#    171030_MB_EB_hs_25yr_BA10_FCU2_NA_H8_AD010_indexed_c  \
# 0                                                 94
# 1                                                 41
# 2                                                445
# 3                                                744
# 4                                               3289
#
#    171030_MB_EB_hs_25yr_BA10_FCU2_NA_H9_AD008_indexed_mc  \
# 0                                                 17
# 1                                                  2
# 2                                                  4
# 3                                                 18
# 4                                                332
#
#    171030_MB_EB_hs_25yr_BA10_FCU2_NA_H9_AD008_indexed_c  \
# 0                                                149
# 1                                                 87
# 2                                                353
# 3                                                658
# 4                                               3624
#
#    171030_MB_EB_hs_25yr_BA10_FCU2_NA_H9_AD010_indexed_mc  \
# 0                                                  7
# 1                                                  8
# 2                                                  2
# 3                                                  7
# 4                                                232
#
#    171030_MB_EB_hs_25yr_BA10_FCU2_NA_H9_AD010_indexed_c
# 0                                                112
# 1                                                149
# 2                                                424
# 3                                                493
# 4                                               2707
#
# [5 rows x 12871 columns]

# %%
# cluster mc_c
df_c = df_input.filter(regex='_c$')
df_mc = df_input.filter(regex='_mc$')

df_mc_c = pd.DataFrame() 
for label, df_sub in df_info.groupby('cluster'):
    samples = df_sub.index.values
    df_mc_c['{}_mc'.format(label)] = df_mc[samples+'_mc'].sum(axis=1)
    df_mc_c['{}_c'.format(label)] = df_c[samples+'_c'].sum(axis=1)

# %%
df_mc_c.head()
# Out:
#     1_mc      1_c   2_mc      2_c   3_mc     3_c   4_mc     4_c   5_mc  \
# 0   2076    52520   1233    60070   1018   29268    750   26618    829
# 1   4184    73188   3138    83262   2653   40202   1439   33946   3088
# 2   2053   208041   1830   237812   1117  120011    773  103874    994
# 3   6413   421223   5903   459901   4859  227663   2499  205847   4667
# 4  99012  1590457  56644  1817594  49233  887356  35255  801392  39443
#
#       5_c  ...    28_mc    28_c  29_mc    29_c  30_mc    30_c  31_mc    31_c  \
# 0   31618  ...      136    4711    195    5927    204    4097     58    4515
# 1   37826  ...      408    7067    754    7719    478    5657    218    6241
# 2  113200  ...      200   24697    175   23022    179   19292     93   16344
# 3  227921  ...      690   42452    785   41725    825   37223    347   34387
# 4  876376  ...     5540  163471   7300  161656   8694  138082   1736  134934
#
#    32_mc   32_c
# 0     39   1272
# 1    162   2375
# 2     71   7525
# 3    183  14980
# 4   3931  58994
#
# [5 rows x 64 columns]

# %%
df_mcc = get_mcc(df_mc_c)
print(df_mcc.shape)
df_mcc.head()
# Out:
# (44567, 32)
#       1_mcc     2_mcc     3_mcc     4_mcc     5_mcc     6_mcc     7_mcc  \
# 0  0.039528  0.020526  0.034782  0.028176  0.026219  0.045911  0.036847
# 1  0.057168  0.037688  0.065992  0.042391  0.081637  0.057624  0.067628
# 2  0.009868  0.007695  0.009307  0.007442  0.008781  0.010330  0.007373
# 3  0.015225  0.012835  0.021343  0.012140  0.020476  0.017512  0.017451
# 4  0.062254  0.031164  0.055483  0.043992  0.045007  0.084981  0.043442
#
#       8_mcc     9_mcc    10_mcc    ...       23_mcc    24_mcc    25_mcc  \
# 0  0.036715  0.013599  0.041699    ...     0.024931  0.046025  0.034296
# 1  0.083495  0.020371  0.056993    ...     0.065295  0.086815  0.101876
# 2  0.010568  0.007783  0.008676    ...     0.008329  0.009053  0.009713
# 3  0.021116  0.016368  0.025082    ...     0.017864  0.024128  0.014335
# 4  0.042624  0.011905  0.043746    ...     0.022586  0.057141  0.054555
#
#      26_mcc    27_mcc    28_mcc    29_mcc    30_mcc    31_mcc    32_mcc
# 0  0.036532  0.050505  0.028869  0.032900  0.049793  0.012846  0.030660
# 1  0.061059  0.075929  0.057733  0.097681  0.084497  0.034930  0.068211
# 2  0.006527  0.009825  0.008098  0.007601  0.009278  0.005690  0.009435
# 3  0.014318  0.034557  0.016254  0.018814  0.022164  0.010091  0.012216
# 4  0.039517  0.044547  0.033890  0.045158  0.062963  0.012866  0.066634
#
# [5 rows x 32 columns]

# %%
# dendrogram 

Z = sch.linkage(df_mcc.rank(pct=True, axis=0).T, method='average', metric='correlation')
fig, ax = plt.subplots(figsize=(6, 12))
sch.dendrogram(Z, ax=ax, orientation='left')
ax.set_yticklabels(
    ['C{} ({} {})'.format(int(label.get_text())+1, 
                       df_annot.loc[int(label.get_text())+1, 'annotation'], 
                       df_annot.loc[int(label.get_text())+1, 'num'], 
                      )
     for label in ax.get_yticklabels()], 
    fontsize=12)
ax.set_xlabel('Metric: Spearman correlation of mCH level', fontsize=12)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
# ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.show()

# %%
# and how shall we merge
