# %%
from __init__ import *
from CEMBA_update_mysql import connect_sql

# %%
ens = 'Ens7'
cluster_type = 'cluster_mCHmCG_lv_npc50_k30'
annotation_type = 'annotation' + cluster_type[len('cluster'):]
engine = connect_sql('CEMBA')

# cluster annotation
sql = """SELECT {}, {} FROM {}""".format(cluster_type, annotation_type, ens)
df_info = pd.read_sql(sql, engine)
df_info = df_info.sort_values(cluster_type).drop_duplicates().set_index(cluster_type)

ens_path = os.path.join(PATH_ENSEMBLES, ens)
n_clusters = len(glob.glob(os.path.join(ens_path, 'allc_merged/allc_merged_mCG_{}_*_{}.tsv'.format(cluster_type, ens))))

# dmr results
input_f = os.path.join(ens_path, 'dmr/dmr_allc_merged_mCG_{}_rms_results_collapsed.tsv'.format(cluster_type))
df = pd.read_table(input_f, index_col=['#chr', 'start', 'end'], dtype={'#chr': object})
# Out:
# /cndd/fangming/venvs/venv_banjo_snmcseq/lib/python3.4/site-packages/numpy/lib/arraysetops.py:466: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
def dmr_counts(ens, n_clusters, cluster_type, df, keys=['hypomethylated_samples', 'hypermethylated_samples']):
    """
    cluster_type examples:
    cluster_type = 'cluster_mCHmCG_lv_npc50_k30'
    
    """
    res_out = []
    for key in keys:
        res_key = []
        res = df.loc[~df[key].isnull(), key].apply(lambda x: x.split(','))
        for i in range(n_clusters):
            res_cluster = res.loc[
                res.apply(lambda x: ('merged_mCG_{}_{}_{}'.format(cluster_type, i+1, ens) in x))]
            res_key.append({cluster_type: i+1, 'n_dmr_{}'.format(key[:4]): res_cluster.shape[0]})
        res_key = pd.DataFrame(res_key).set_index(cluster_type)
        res_out.append(res_key)
    return pd.concat(res_out, axis=1)

# %%
df_ndmr = dmr_counts(ens, n_clusters, cluster_type, df)
df_ndmr = pd.merge(df_info, df_ndmr, left_index=True, right_index=True)

# %%
df_ndmr.head()
# Out:
#                             annotation_mCHmCG_lv_npc50_k30  n_dmr_hypo  \
# cluster_mCHmCG_lv_npc50_k30
# 1                                                    mL2/3      260680
# 2                                                      mL4      195808
# 3                                                    mL2/3      210356
# 4                                                    mL6-2      141782
# 5                                                    mL5-1       77352
#
#                              n_dmr_hype
# cluster_mCHmCG_lv_npc50_k30
# 1                                 21848
# 2                                 35638
# 3                                 19806
# 4                                 38398
# 5                                 13204

# %%
df.head()
# Out:
#                       number_of_dms hypermethylated_samples  \
# #chr start   end
# 1    3013473 3013473              1                     NaN
#      3023075 3023075              1                     NaN
#      3027398 3027398              1                     NaN
#      3034472 3034472              1                     NaN
#      3044313 3044403              3                     NaN
#
#                                                  hypomethylated_samples  \
# #chr start   end
# 1    3013473 3013473                                                NaN
#      3023075 3023075     merged_mCG_cluster_mCHmCG_lv_npc50_k30_16_Ens7
#      3027398 3027398      merged_mCG_cluster_mCHmCG_lv_npc50_k30_3_Ens7
#      3034472 3034472      merged_mCG_cluster_mCHmCG_lv_npc50_k30_3_Ens7
#      3044313 3044403  merged_mCG_cluster_mCHmCG_lv_npc50_k30_13_Ens7...
#
#                       methylation_level_merged_mCG_cluster_mCHmCG_lv_npc50_k30_10_Ens7  \
# #chr start   end
# 1    3013473 3013473                                           1.000000
#      3023075 3023075                                           1.000000
#      3027398 3027398                                           0.636364
#      3034472 3034472                                           0.666667
#      3044313 3044403                                           0.931034
#
#                       methylation_level_merged_mCG_cluster_mCHmCG_lv_npc50_k30_11_Ens7  \
# #chr start   end
# 1    3013473 3013473                                           0.750000
#      3023075 3023075                                           0.833333
#      3027398 3027398                                           0.695652
#      3034472 3034472                                           0.714286
#      3044313 3044403                                           0.942857
#
#                       methylation_level_merged_mCG_cluster_mCHmCG_lv_npc50_k30_12_Ens7  \
# #chr start   end
# 1    3013473 3013473                                           1.000000
#      3023075 3023075                                           1.000000
#      3027398 3027398                                           0.500000
#      3034472 3034472                                           0.857143
#      3044313 3044403                                           0.346154
#
#                       methylation_level_merged_mCG_cluster_mCHmCG_lv_npc50_k30_13_Ens7  \
# #chr start   end
# 1    3013473 3013473                                           0.833333
#      3023075 3023075                                           1.000000
#      3027398 3027398                                           0.625000
#      3034472 3034472                                           1.000000
#      3044313 3044403                                           0.310345
#
#                       methylation_level_merged_mCG_cluster_mCHmCG_lv_npc50_k30_14_Ens7  \
# #chr start   end
# 1    3013473 3013473                                           1.000000
#      3023075 3023075                                           0.909091
#      3027398 3027398                                           0.272727
#      3034472 3034472                                           0.500000
#      3044313 3044403                                           1.000000
#
#                       methylation_level_merged_mCG_cluster_mCHmCG_lv_npc50_k30_15_Ens7  \
# #chr start   end
# 1    3013473 3013473                                           1.000000
#      3023075 3023075                                           1.000000
#      3027398 3027398                                           0.333333
#      3034472 3034472                                           1.000000
#      3044313 3044403                                           0.950000
#
#                       methylation_level_merged_mCG_cluster_mCHmCG_lv_npc50_k30_16_Ens7  \
# #chr start   end
# 1    3013473 3013473                                           1.000000
#      3023075 3023075                                           0.363636
#      3027398 3027398                                           0.384615
#      3034472 3034472                                           0.200000
#      3044313 3044403                                           1.000000
#
#                                                    ...                                 \
# #chr start   end                                   ...
# 1    3013473 3013473                               ...
#      3023075 3023075                               ...
#      3027398 3027398                               ...
#      3034472 3034472                               ...
#      3044313 3044403                               ...
#
#                       methylation_level_merged_mCG_cluster_mCHmCG_lv_npc50_k30_26_Ens7  \
# #chr start   end
# 1    3013473 3013473                                                NaN
#      3023075 3023075                                                0.8
#      3027398 3027398                                                0.5
#      3034472 3034472                                                1.0
#      3044313 3044403                                                1.0
#
#                       methylation_level_merged_mCG_cluster_mCHmCG_lv_npc50_k30_27_Ens7  \
# #chr start   end
# 1    3013473 3013473                                           1.000000
#      3023075 3023075                                           1.000000
#      3027398 3027398                                           0.000000
#      3034472 3034472                                                NaN
#      3044313 3044403                                           0.666667
#
#                       methylation_level_merged_mCG_cluster_mCHmCG_lv_npc50_k30_2_Ens7  \
# #chr start   end
# 1    3013473 3013473                                           0.434783
#      3023075 3023075                                           1.000000
#      3027398 3027398                                           0.536585
#      3034472 3034472                                           0.846154
#      3044313 3044403                                           0.984848
#
#                       methylation_level_merged_mCG_cluster_mCHmCG_lv_npc50_k30_3_Ens7  \
# #chr start   end
# 1    3013473 3013473                                           0.700000
#      3023075 3023075                                           0.846154
#      3027398 3027398                                           0.038462
#      3034472 3034472                                           0.166667
#      3044313 3044403                                           0.959184
#
#                       methylation_level_merged_mCG_cluster_mCHmCG_lv_npc50_k30_4_Ens7  \
# #chr start   end
# 1    3013473 3013473                                           0.875000
#      3023075 3023075                                           1.000000
#      3027398 3027398                                           0.600000
#      3034472 3034472                                           0.714286
#      3044313 3044403                                           0.436364
#
#                       methylation_level_merged_mCG_cluster_mCHmCG_lv_npc50_k30_5_Ens7  \
# #chr start   end
# 1    3013473 3013473                                           0.750000
#      3023075 3023075                                           1.000000
#      3027398 3027398                                           0.619048
#      3034472 3034472                                           0.500000
#      3044313 3044403                                           1.000000
#
#                       methylation_level_merged_mCG_cluster_mCHmCG_lv_npc50_k30_6_Ens7  \
# #chr start   end
# 1    3013473 3013473                                           0.900000
#      3023075 3023075                                           1.000000
#      3027398 3027398                                           0.750000
#      3034472 3034472                                           1.000000
#      3044313 3044403                                           0.971429
#
#                       methylation_level_merged_mCG_cluster_mCHmCG_lv_npc50_k30_7_Ens7  \
# #chr start   end
# 1    3013473 3013473                                           0.333333
#      3023075 3023075                                           1.000000
#      3027398 3027398                                           0.789474
#      3034472 3034472                                           1.000000
#      3044313 3044403                                           0.972222
#
#                       methylation_level_merged_mCG_cluster_mCHmCG_lv_npc50_k30_8_Ens7  \
# #chr start   end
# 1    3013473 3013473                                           0.714286
#      3023075 3023075                                           1.000000
#      3027398 3027398                                           0.736842
#      3034472 3034472                                           0.916667
#      3044313 3044403                                           1.000000
#
#                       methylation_level_merged_mCG_cluster_mCHmCG_lv_npc50_k30_9_Ens7
# #chr start   end
# 1    3013473 3013473                                           0.230769
#      3023075 3023075                                           1.000000
#      3027398 3027398                                           0.941176
#      3034472 3034472                                           1.000000
#      3044313 3044403                                           1.000000
#
# [5 rows x 30 columns]

# %%
print(df.shape)
df_hypo = df.loc[(df['number_of_dms']>=3) & (~df['hypomethylated_samples'].isnull()), 'hypomethylated_samples'].apply(lambda x: x.split(','))
df_hyper = df.loc[(df['number_of_dms']>=3) & (~df['hypermethylated_samples'].isnull()), 'hypermethylated_samples'].apply(lambda x: x.split(','))

print(df_hypo.shape)
print(df_hyper.shape)
# Out:
# (1162175, 30)
# (489138,)
# (255213,)

# %%
df_hypo.head()
# Out:
# #chr  start    end
# 1     3044313  3044403    [merged_mCG_cluster_mCHmCG_lv_npc50_k30_13_Ens...
#       3093908  3094064      [merged_mCG_cluster_mCHmCG_lv_npc50_k30_7_Ens7]
#       3113717  3114036     [merged_mCG_cluster_mCHmCG_lv_npc50_k30_21_Ens7]
#       3118790  3118936    [merged_mCG_cluster_mCHmCG_lv_npc50_k30_2_Ens7...
#       3130148  3130281      [merged_mCG_cluster_mCHmCG_lv_npc50_k30_2_Ens7]
# Name: hypomethylated_samples, dtype: object

# %%
for i in range(n_clusters):
    df_hypo_cluster = df_hypo.loc[
        df_hypo.apply(lambda x: ('merged_mCG_{}_{}_{}'.format(cluster_type, i+1, ens) in x))]
    output = os.path.join(ens_path, 'dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst{}.bed'.format(i+1))
    print(output)
    print(df_hypo_cluster.shape)
# Out:
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst1.bed
# (184304,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst2.bed
# (138092,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst3.bed
# (139804,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst4.bed
# (102299,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst5.bed
# (57663,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst6.bed
# (42020,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst7.bed
# (38062,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst8.bed
# (84889,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst9.bed
# (67342,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst10.bed
# (34520,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst11.bed
# (56321,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst12.bed
# (55928,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst13.bed
# (43587,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst14.bed
# (44915,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst15.bed
# (12161,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst16.bed
# (73661,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst17.bed
# (86148,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst18.bed
# (24332,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst19.bed
# (24948,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst20.bed
# (70145,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst21.bed
# (28973,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst22.bed
# (23184,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst23.bed
# (64697,)
# /cndd/Public_Datasets/CEMBA/snmCSeq/Ensembles/Ens7/dmr/dmr_allc_merged_mCG_cluster_mCHmCG_lv_npc50_k30_clst24.bed
# (10601,)

# %%
# Out:
# (184304,)
