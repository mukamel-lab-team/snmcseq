# %%
import matplotlib.pyplot as plt
import seaborn as sns


from __init__ import *
import snmcseq_utils

# %%
# rob's rna seq data

clst_f = '/home/rloughna/Voytek/ABA/single_cell_rna/clustering/all_cells_cpm/clustering_anot_k_100.csv'
tsne_f = '/home/rloughna/Voytek/ABA/single_cell_rna/tsne_coord_50perp_200pcs.csv'
meta_f = '/home/rloughna/Voytek/ABA/single_cell_rna/data/columns-nuclei.csv'

df_clst = pd.read_table(clst_f, index_col='sample')

df_tsne = pd.read_csv(tsne_f, header=0, names=['sample', 'tsne_x', 'tsne_y'])
df_tsne['sample'] = [sample[:-4] for sample in df_tsne['sample']]
df_tsne = df_tsne.set_index('sample')

df_meta = pd.read_csv(meta_f)
df_meta['exp_component_name'] = [sample[:-4] for sample in df_meta['exp_component_name']]
df_meta = df_meta.set_index('exp_component_name')

df_info = pd.concat([df_clst, df_tsne, df_meta], axis=1)

print(df_clst.shape)
print(df_tsne.shape)
print(df_meta.shape)
print(df_info.shape)

df_info.head()
print(df_info.columns.tolist())
# Out:
# (15928, 1)
# (15928, 2)
# (15928, 55)
# (15928, 58)
# ['cluster_ID', 'tsne_x', 'tsne_y', 'alignment_id', 'donor_id', 'gender', 'organism', 'sampling_region', 'roi', 'facs_population_plan', 'sample_type', 'facs_well', 'facs_container', 'rna_amplification_set', 'rna_amplification', 'percent_cdna_longer_than_400bp', 'amplified_quantity_ng', 'library_prep_set', 'library_prep', 'avg_size_bp', 'quantification_fmol', 'batch_sent_for_sequencing', 'tube_sent_for_sequencing', 'total_reads', 'rsem_reads_aligned_mRNA_gDNA', 'rsem_percent_reads_aligned_to_mrna', 'rsem_percent_reads_aligned_to_genome_only', 'rsem_percent_reads_aligned_total', 'percent_reads_aligned_to_exons', 'percent_reads_aligned_to_rrna', 'percent_reads_aligned_to_trna', 'percent_reads_aligned_to_other_ncrna', 'percent_reads_aligned_to_mt_exons', 'percent_reads_aligned_to_mt_rrna', 'percent_reads_aligned_to_mt_trna', 'percent_reads_aligned_to_mt_other_ncrna', 'percent_reads_aligned_intron', 'percent_reads_aligned_to_ecoli', 'percent_reads_aligned_to_synthetic_constructs', 'percent_reads_aligned_total', 'percent_unique_reads', 'complexity_aatt', 'complexity_acgt', 'complexity_agct', 'complexity_at', 'complexity_catg', 'complexity_ccgg', 'complexity_cg', 'complexity_gatc', 'complexity_gc', 'complexity_ta', 'cpm>0_gene_count', 'cpm>1_gene_count', 'cpm>4_gene_count', 'cpm>8_gene_count', 'cpm>16_gene_count', 'cpm>32_gene_count', 'cpm>64_gene_count']
# LS-15005h_S01_E    Nuclei
# LS-15005h_S02_E    Nuclei
# LS-15005h_S03_E    Nuclei
# LS-15005h_S04_E    Nuclei
# LS-15005h_S05_E    Nuclei
# Name: sample_type, dtype: object

# %%
f = '/home/rloughna/Voytek/ABA/single_cell_rna/log_tpm.csv'
df = pd.read_csv(f, index_col='name')
df.columns = [col[:-4] for col in df.columns]
print(df.shape)
df.head()
# Out:
# (28231, 15928)
#             LS-15005h_S01_E1-50  LS-15005h_S02_E1-50  LS-15005h_S03_E1-50  \
# name
# WASH7P                 0.695975                 -6.0             0.208455
# MIR1302-11            -6.000000                 -6.0            -6.000000
# FAM138A               -6.000000                 -6.0            -6.000000
# OR4G4P                -6.000000                 -6.0            -6.000000
# OR4G11P               -6.000000                 -6.0            -6.000000
#
#             LS-15005h_S04_E1-50  LS-15005h_S05_E1-50  LS-15005h_S06_E1-50  \
# name
# WASH7P                     -6.0                 -6.0                 -6.0
# MIR1302-11                 -6.0                 -6.0                 -6.0
# FAM138A                    -6.0                 -6.0                 -6.0
# OR4G4P                     -6.0                 -6.0                 -6.0
# OR4G11P                    -6.0                 -6.0                 -6.0
#
#             LS-15005h_S07_E1-50  LS-15005h_S10_E1-50  LS-15005h_S11_E1-50  \
# name
# WASH7P                     -6.0                 -6.0                 -6.0
# MIR1302-11                 -6.0                 -6.0                 -6.0
# FAM138A                    -6.0                 -6.0                 -6.0
# OR4G4P                     -6.0                 -6.0                 -6.0
# OR4G11P                    -6.0                 -6.0                 -6.0
#
#             LS-15005h_S12_E1-50         ...          SQ-80016_S85_E1-50  \
# name                                    ...
# WASH7P                  0.24045         ...                        -6.0
# MIR1302-11             -6.00000         ...                        -6.0
# FAM138A                -6.00000         ...                        -6.0
# OR4G4P                 -6.00000         ...                        -6.0
# OR4G11P                -6.00000         ...                        -6.0
#
#             SQ-80016_S86_E1-50  SQ-80016_S87_E1-50  SQ-80016_S89_E1-50  \
# name
# WASH7P                    -6.0                -6.0                -6.0
# MIR1302-11                -6.0                -6.0                -6.0
# FAM138A                   -6.0                -6.0                -6.0
# OR4G4P                    -6.0                -6.0                -6.0
# OR4G11P                   -6.0                -6.0                -6.0
#
#             SQ-80016_S90_E1-50  SQ-80016_S91_E1-50  SQ-80016_S92_E1-50  \
# name
# WASH7P                    -6.0            1.081534            0.205052
# MIR1302-11                -6.0           -6.000000           -6.000000
# FAM138A                   -6.0           -6.000000           -6.000000
# OR4G4P                    -6.0           -6.000000           -6.000000
# OR4G11P                   -6.0           -6.000000           -6.000000
#
#             SQ-80016_S93_E1-50  SQ-80016_S94_E1-50  SQ-80016_S95_E1-50
# name
# WASH7P                    -6.0                -6.0                -6.0
# MIR1302-11                -6.0                -6.0                -6.0
# FAM138A                   -6.0                -6.0                -6.0
# OR4G4P                    -6.0                -6.0                -6.0
# OR4G11P                   -6.0                -6.0                -6.0
#
# [5 rows x 15928 columns]

# %%
snmcseq_utils.plot_tsne_labels(df_info, tc='cluster_ID', legend_mode=0)
snmcseq_utils.plot_tsne_labels(df_info, tc='donor_id', legend_mode=0)

# %% [markdown]
# # annotate clusters

# %%
gene_name = 'TYRO3'

# tsne 
sr_gene = df.loc[gene_name]
df_gene = pd.concat((df_info, sr_gene), axis=1)
snmcseq_utils.plot_tsne_values(df_gene, tc=gene_name)

# boxplot
# fig, ax = plt.subplots()
# sns.boxplot(x='cluster_ID', y=gene_name, data=df_gene, ax=ax)
# ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# plt.show()

# mean plot
res_mean = df_gene[['cluster_ID', gene_name]].groupby('cluster_ID').mean()
plt.plot(res_mean.values)
plt.show()

# %%
annot_list = []
# res_mean = df_gene[['cluster_ID', 'GAD1']].groupby('cluster_ID').mean()
# plt.plot(res_mean.values)
# plt.xticklabels(res_mean.index.values)

gene_name = 'MEF2C'
sr_gene = df.loc[gene_name]
df_gene = pd.concat((df_info, sr_gene), axis=1)
res_mean = df_gene[['cluster_ID', gene_name]].groupby('cluster_ID').mean()
for cluster_id in res_mean.loc[res_mean[gene_name] < -2].index:
    annot_list.append({'cluster_ID': cluster_id,
                      'cluster_annotation': 'Glia'})

gene_name = 'SATB2'
sr_gene = df.loc[gene_name]
df_gene = pd.concat((df_info, sr_gene), axis=1)
res_mean = df_gene[['cluster_ID', gene_name]].groupby('cluster_ID').mean()
for cluster_id in res_mean.loc[res_mean[gene_name] > -3].index:
    annot_list.append({'cluster_ID': cluster_id,
                      'cluster_annotation': 'Ex'})

gene_name = 'GAD1'
sr_gene = df.loc[gene_name]
df_gene = pd.concat((df_info, sr_gene), axis=1)
res_mean = df_gene[['cluster_ID', gene_name]].groupby('cluster_ID').mean()
for cluster_id in res_mean.loc[res_mean[gene_name] > 1].index:
    annot_list.append({'cluster_ID': cluster_id,
                      'cluster_annotation': 'In'})
annot_list

df_annot = pd.DataFrame(annot_list)
df_annot.sort_values('cluster_ID').head()
# Out:
#     cluster_ID cluster_annotation
# 3    cluster_1                 Ex
# 4   cluster_10                 Ex
# 17  cluster_11                 In
# 5   cluster_12                 Ex
# 6   cluster_13                 Ex

# %%
df_info2 = pd.merge(df_info, df_annot, on='cluster_ID', how='left')
df_info3 = pd.merge(df_info, df_annot, on='cluster_ID', how='inner')
snmcseq_utils.plot_tsne_labels(df_info2, tc='cluster_annotation')
snmcseq_utils.plot_tsne_labels(df_info3, tc='cluster_annotation')

# %%
df_info3.shape
# Out:
# (15843, 59)

# %% [markdown]
# # number of cells in each cluster across datasets
#
# - ANOVA
# - PCA-LDA
# - Marker genes
